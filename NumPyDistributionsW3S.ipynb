# %% [markdown]
# <a href="https://colab.research.google.com/github/mazarrazi/notes_code_log/blob/main/NumPyDistributionsW3S.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NumPy contd.

# Random module, Seaborn module & Distributions will be covered in this ipynb

# %%
# 14  Random Numbers in NumPy

# Random number does NOT mean a different number every time. Random means something that can not be predicted logically.

# Pseudo Random and True Random.
#  Computers work on programs, and programs are definitive set of instructions. So it means there must be some algorithm to generate a random number as well.
#   If there is a program to generate random number it can be predicted, thus it is not truly random.
#    Random numbers generated through a generation algorithm are called pseudo random. Can we make truly random numbers?
#     Yes. In order to generate a truly random number on our computers we need to get the random data from some outside source. This outside source is generally our keystrokes, mouse movements, data on network etc.
#      We do not need truly random numbers, unless it is related to security (e.g. encryption keys) or the basis of application is the randomness (e.g. Digital roulette wheels).

# %%
# 14.1  Generate Random Number

# NumPy offers the random module to work with random numbers.

# Generating a random integer from 0 to 100:

import numpy as np

from numpy import random


acz = random.randint(100)  # generates one random number, value of that number would be bt. 0 to 100

print(acz)
# Out:
# 36

# %%
# 14.2  Generate Random Float

# The random module's rand() method returns a random float between 0 and 1.

acz = random.rand()  # generates one random float, value of that float would be bt. 0 to 1

print(acz)
# Out:
# 0.969749800797542

# %%
# 14.3  Generate Random Array

# In NumPy we work with arrays, and you can use the two methods from the above examples to make random arrays.
# The randint() method takes a size parameter where you can specify the shape of an array.

# Generating a 1-D array containing 3 random integers from 0 to 100:

acz = random.randint(100, size=3)

print(acz)
# Out:
# [ 9 79 16]

# %%
#  Generate a 2-D array with 3 rows, each row containing 5 random integers from 0 to 100:

acz = random.randint(100, size=(3,5))

print(acz)
# Out:
# [[88 13 27 61 45]
#  [90 37 81 53 65]
#  [65 59 11 93 74]]

# %%
# 14.4  Floats (same but with floats)

# The rand() method also allows you to specify the shape of the array.

# Generatng a 1-D array containing 5 random floats:

acz = random.rand(3)  # the 3 specified here is Dimension not max limit, note that float value will be bt. 0 & 1

print(acz)
# Out:
# [0.82717538 0.80413646 0.32374406]

# %%
# Generating a 2-D array with 3 rows, each row containing 5 random numbers:

acz = random.rand(3, 5)   # the 3 & 5 specified here is Dimension not max limit, note that float value will be bt. 0 & 1

print(acz)
# Out:
# [[0.25470803 0.62250265 0.46695044 0.97830568 0.89337779]
#  [0.22488617 0.70838186 0.19787534 0.81894215 0.5217424 ]
#  [0.38029248 0.54816617 0.62361902 0.01851036 0.03225113]]

# %%
# 14.5  Generate Random Number From Array

# The choice() method allows you to generate a random value based on an array of values.
# The choice() method takes an array as a parameter and randomly returns one of the values.

# Return one of the values in an array

acz = random.choice([3, 5, 7, 2])

print(acz)
# Out:
# 7

# %%
# The choice() method also allows you to return an array of values.
# Add a size parameter to specify the shape of the array.

# Generating a 2-D array that consists of the values in the array parameter (3, 5, 7, and 9)

acz = random.choice([1, 4, 6, 9], size=(3,5))

print(acz)
# Out:
# [[1 6 1 1 4]
#  [1 6 9 4 9]
#  [4 4 4 4 1]]

# %%
# 15  Random Data Distribution

# Data Distribution is a list of all possible values, and how often each value occurs.
#  A random distribution is a set of random numbers that follow a certain probability density function.

# Probability Density Function: A function that describes a continuous probability. i.e. probability of all values in an array.

# We can generate random numbers based on defined probabilities using the choice() method of the random module.
#  The choice() method allows us to specify the probability for each value.
#   The probability is set by a number between 0 and 1, where 0 means that the value will never occur and 1 means that the value will always occur.

# %%
# Generating a 1-D array containing 100 values, where each value has to be 3, 5, 7 or 9.

acz = random.choice([1, 5, 7, 2], p=[0.1, 0.3, 0.6, 0.0], size=(10))  # adding all values in p should total to 1.0

print(acz)

# The probability for the value to be 3 is set to be 0.1
# The probability for the value to be 5 is set to be 0.3
# The probability for the value to be 7 is set to be 0.6
# The probability for the value to be 9 is set to be 0
# Even if you run the example above 100 times, the value 9 will never occur.

# The sum of all probability numbers should be 1.
# Out:
# [5 7 5 7 7 5 5 5 7 7]

# %%
#  You can return arrays of any shape and size by specifying the shape in the size parameter.

acz = random.choice([1, 3, 7, 5], p=[0.1, 0.3, 0.6, 0.0], size =(3,5))

print(acz)
# Out:
# [[7 3 1 1 7]
#  [3 7 7 7 7]
#  [7 3 7 7 3]]

# %%
# 16  Random Permutations

# A permutation refers to an arrangement of elements. e.g. [3, 2, 1] is a permutation of [1, 2, 3] and vice-versa.
#  The NumPy Random module provides two methods for this: shuffle() and permutation().

# The shuffle() method makes changes to the original array.
# The permutation() method returns a re-arranged array (and leaves the original array un-changed).

# %%
# 16.1  Shuffling Arrays

# Shuffle means changing arrangement of elements in-place. i.e. in the array itself.

acz = np.array([1,2,3,4,5])

random.shuffle(acz)  # note: alters original data

print(acz)
# Out:
# [2 3 5 4 1]

# %%
# 16.2  Generating Permutation of Arrays

# Generate a random permutation of elements of following array:

acz = np.array([1,2,3,4,5])

print(random.permutation(acz))  # permutation means all possible orders of arrangement of the available elements
# Out:
# [2 4 1 5 3]

# %%
# 17  Seaborn

# Visualize Distributions With Seaborn
#  Seaborn is a library that uses Matplotlib underneath to plot graphs. It will be used to visualize random distributions.

# Distplots
#  Distplot stands for distribution plot, it takes as input an array and plots a curve corresponding to the distribution of points in the array.

# %%
# 17.1  Plotting a Distplot

import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0,1,2,3,4,5])

plt.show()
# Out:
# <ipython-input-77-7a017cf02d81>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4,5])

# %%
# 17.2  Plotting a Distplot Without the Histogram

import matplotlib.pyplot as plt

import seaborn as sns

sns.distplot([0,1,2,3,4,5], hist=False)

plt.show()
# Out:
# <ipython-input-78-1b3395bc60bf>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4,5], hist=False)

# %%
# Note: We will be using: sns.distplot(arr, hist=False) to visualize random distributions

# %%
# 18 Normal Distribution (Gaussian Distribution)

# It fits the probability distribution of many events, eg. IQ Scores, Heartbeat etc.

# Use the random.normal() method to get a Normal Data Distribution.

# It has three parameters:
#  loc - (Mean) where the peak of the bell exists.
#  scale - (Standard Deviation) how flat the graph distribution should be.
#  size - The shape of the returned array.

# %%
# 18.1  Generating a random normal distribution of size 2x3:

from numpy import random

arr = random.normal(size=(2,3))

print(arr)
# Out:
# [[ 0.29799805 -0.24056389  1.43234253]
#  [-0.8897807  -1.21586366 -2.00839297]]

# %%
# Generating a random normal distribution of size 2x3 with mean at 1 and standard deviation of 2

arr = random.normal(loc=1, scale=2, size=(2,3))

print(arr)
# Out:
# [[-1.47550131 -2.1823019  -0.32129336]
#  [-1.65805739 -1.28878487  2.01405047]]

# %%
# why there are values in negative?

#  The values in the array are negative because they are random numbers generated from a standard normal distribution,
#   which is a symmetric distribution centered around 0.
#    In a standard normal distribution, about half of the values will be negative, and the other half will be positive.

#     The negative and positive values represent deviations from the mean, with negative values indicating values below the mean, and positive values indicating values above the mean.
#      Since these values are randomly generated, you can get a mix of positive and negative numbers in the output.

# %%
# 18.2  Visualization of Normal Distribution

import numpy as np
from numpy import random

import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.normal(size=1000), hist=False)   #  Format: sns.distplot(arr,hist) .... we generated random normal distribution in arr place
plt.show()
# Out:
# <ipython-input-84-bfa9cdc5e5a2>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000), hist=False)   #  Format: sns.distplot(arr,hist) .... we generated random normal distribution in arr place

# %%
# same, using arr directly

arr = random.normal(loc=1, scale=2, size=(3,5))  # random.normal creates random numbers which follows these conditions (loc=1, scale=2, size=(3, 5))

sns.distplot(arr, hist=False)
plt.show()
# Out:
# <ipython-input-85-64809b1d5236>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(arr, hist=False)

# %%
# Note: The curve of a Normal Distribution is also known as the Bell Curve because of the bell-shaped curve.

# %%
# 19  Binomial Distribution

# Binomial Distribution is a Discrete Distribution.

# It describes the outcome of binary scenarios, e.g. toss of a coin, it will either be head or tails.

# It has three parameters:
#   n - number of trials.
#   p - probability of occurence of each trial (e.g. for toss of a coin 0.5 each).
#   size - The shape of the returned array.

# %%
#  Given 10 trials for coin toss generate 10 data points:

acz = random.binomial(n=10, p=0.5, size=(10))

print(acz)
# Out:
# [6 5 8 4 6 8 3 5 2 5]

# %%
acz = random.binomial(n=1, p=0.5, size=(10))

print(acz)
# Out:
# [0 1 1 0 0 0 1 0 0 1]

# %%
# 19.1  Visualization of Binomial Distribution

sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)

plt.show()
# Out:
# <ipython-input-90-437be6196f5f>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)

# %%
sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=True)

plt.show()
# Out:
# <ipython-input-91-98484bb3ba7d>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=True)

# %%
# similar method but outputs may vary

arr = random.binomial(n=10, p=0.5, size=1000)
sns.distplot(arr, hist=True, kde=True)
plt.show()
# Out:
# <ipython-input-92-5e0a8db094e6>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(arr, hist=True, kde=True)

# %%
# Histograms are used for discrete or discretized continuous data.
#  They show how data points are distributed in predefined bins, and the bars represent frequencies or counts within those bins.
#   They provide a discrete view of data distribution.

# Kernel Density Estimation (KDE) is used for continuous data.
#  It creates a smooth curve to estimate the underlying continuous probability distribution of the data.
#   It provides a continuous and smooth view of data distribution.

# %%
# 19.2  Difference Between Normal and Binomial Distribution

# The main difference is that normal distribution is continous whereas binomial is discrete,
#  but if there are enough data points it will be quite similar to normal distribution with certain loc and scale.

sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')

sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')

plt.show()
# Out:
# <ipython-input-94-0bfe32a6773c>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
# <ipython-input-94-0bfe32a6773c>:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# 20  Poisson Distribution

# Poisson Distribution is a Discrete Distribution.

# It estimates how many times an event can happen in a specified time. e.g. If someone eats twice a day what is the probability he will eat thrice?

# It has two parameters:
#   lam - rate or known number of occurrences e.g. 2 for above problem.
#   size - The shape of the returned array.

# %%
#  Generating a random 1x10 distribution for occurrence 2

arr = random.poisson(lam=2, size=10)  # the mean of the output should be close to the specified lam, i.e. lam=2 here

print(arr)

mean_of_output = np.mean(arr)
print(mean_of_output)
# Out:
# [5 0 1 1 6 2 3 4 4 1]
# 2.7

# %%
# same

arr = random.poisson(lam=650, size=10)  # the mean of the output should be close to the specified lam, i.e. lam=650 here

print(arr)

mean_of_output = np.mean(arr)
print(mean_of_output)
# Out:
# [685 627 653 683 595 647 608 650 676 652]
# 647.6

# %%
# 20.1  Visualization of Poisson Distribution

sns.distplot(random.poisson(lam=2, size=1000), kde=False, color='indigo')

plt.show()
# Out:
# <ipython-input-98-88575547ce7a>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.poisson(lam=2, size=1000), kde=False, color='indigo')

# %%
# same but with kde

sns.distplot(random.poisson(lam=2, size=1000), color='black')

plt.show()
# Out:
# <ipython-input-99-ab36d55b7a27>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.poisson(lam=2, size=1000), color='black')

# %%
# 20.2  Difference Between Normal and Poisson Distribution

# Normal distribution is continuous whereas poisson is discrete.

# But we can see that similar to binomial for a large enough poisson distribution it will become similar to normal distribution with certain std dev and mean.


sns.distplot(random.normal(loc=50, scale=7, size=1000), hist=False, label='normal', color='green')

sns.distplot(random.poisson(lam=50, size=1000), hist=False, label='poisson', color='red')

plt.show()
# Out:
# <ipython-input-100-e7b80504f782>:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=7, size=1000), hist=False, label='normal', color='green')
# <ipython-input-100-e7b80504f782>:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# 20.3  Difference Between Binomial and Poisson Distribution

# Binomial distribution only has two possible outcomes, whereas poisson distribution can have unlimited possible outcomes.

# But for very large n and near-zero p binomial distribution is near identical to poisson distribution such that n * p is nearly equal to lam.

sns.distplot(random.binomial(n=1000, p=0.01, size=1000), hist=False, label='binomial', color='green')

sns.distplot(random.poisson(lam=10, size=1000), hist=False, color='red')

plt.show()
# Out:
# <ipython-input-101-e554c8506874>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=1000, p=0.01, size=1000), hist=False, label='binomial', color='green')
# <ipython-input-101-e554c8506874>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# 21  Uniform Distribution

# Used to describe probability where every event has equal chances of occuring.
# E.g. Generation of random numbers.

# It has three parameters:
#   low -- lower bound, default 0 .0.
#   high -- upper bound, default 1.0.
#   size -- The shape of the returned array.

# %%
# Creating a 2x3 uniform distribution sample:

acz = random.uniform(size=(2,3))

print(acz)
# Out:
# [[0.95057187 0.61865603 0.12897724]
#  [0.66995582 0.69012053 0.94064552]]

# %%
# same

acz = random.uniform(low=5, high=8, size=(2,3))

print(acz)
# Out:
# [[7.25920303 6.33346256 5.74976074]
#  [5.20518296 6.55419939 6.30678381]]

# %%
# 21.1  Visualization of Uniform Distribution

sns.distplot(random.uniform(size=(1000)), hist=False) # by default low=0 high=1 so all 1000 samples will be bt. 0 & 1

plt.show()
# Out:
# <ipython-input-105-de107208dfb3>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.uniform(size=(1000)), hist=False) # by default low=0 high=1 so all 1000 samples will be bt. 0 & 1

# %%
# 22 Logistic Distribution

# Logistic Distribution is used to describe growth.

# Used extensively in machine learning in logistic regression, neural networks etc.

# It has three parameters:
#   loc - mean, where the peak is. Default 0.
#   scale - standard deviation, the flatness of distribution. Default 1.
#   size - The shape of the returned array.

# %%
# Generating a 2x3 samples from a logistic distribution with mean at 1 and stddev 2.0:

acz = random.logistic(loc=1, scale=2, size=(2,3))

print(acz)
# Out:
# [[ 3.04847552 -1.66537913 -0.56934008]
#  [-0.44485831  2.71870459  4.58165649]]

# %%
# 22.1  Visualization of Logistic Distribution

sns.distplot(random.logistic(loc=1, scale=2, size=(2,3)), hist=False)

plt.show()
# Out:
# <ipython-input-108-233159399111>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.logistic(loc=1, scale=2, size=(2,3)), hist=False)

# %%
# same

acz = random.logistic(loc=1, scale=2, size=(2,3))
sns.distplot(acz, hist=False)
# Out:
# <ipython-input-109-92d90ef81e3b>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(acz, hist=False)
# <Axes: ylabel='Density'>

# %%
# why outputs vary?

# sns.distplot(random.logistic(loc=1, scale=2, size=(2,3)))
# plt.show()

# and
# this,

# acz = random.logistic(loc=1, scale=2, size=(2,3))
# sns.distplot(acz)
# produce different outputs?


#  The first snippet creates separate distribution plots for each row,
#   while the second snippet treats the entire 2D array as one dataset and plots a single distribution.
#    The difference is in how sns.distplot interprets the shape of the input data and plots accordingly.


# If you want to visualize and compare the distribution of the rows separately, you should use the first method
# If you want to visualize the distribution of all the values combined (treating the entire 2D array as one dataset), you should use the second method

# %%
# 22.2  Difference Between Logistic and Normal Distribution

# Both distributions are near identical, but logistic distribution has more area under the tails, meaning it represents more possibility of occurrence of an event further away from mean.

# For higher value of scale (standard deviation) the normal and logistic distributions are near identical apart from the peak.

sns.distplot(random.normal(scale=2, size=1000), hist=False, color='green')

sns.distplot(random.logistic(size=1000), hist=False, color='red')

plt.show()
# Out:
# <ipython-input-111-9f0ca56cab82>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(scale=2, size=1000), hist=False, color='green')
# <ipython-input-111-9f0ca56cab82>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# 23  Exponential Distribution

# Exponential distribution is used for describing time till next event e.g. failure/success etc.

# It has two parameters:
#   scale - inverse of rate ( see lam in poisson distribution ) defaults to 1.0.
#   size - The shape of the returned array.

# %%
# 23  Generating a sample for exponential distribution with 2.0 scale with 2x3 size:

acz = random.exponential(scale=2, size=(2,3))

print(acz)
# Out:
# [[0.56577708 1.06459923 3.04824164]
#  [0.08468668 0.66626213 1.66958672]]

# %%
# 23.1  Visualization of Exponential Distribution

sns.distplot(random.exponential(size=1000), hist=False)

plt.show()
# Out:
# <ipython-input-114-aa9bd3862927>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.exponential(size=1000), hist=False)

# %%
# 23.2  Relation Between Poisson and Exponential Distribution

# Poisson distribution deals with number of occurences of an event in a time period
#  whereas exponential distribution deals with the time between these events.

# %%
# 24  Chi Square Distribution

# Chi Square distribution is used as a basis to verify the hypothesis.

# It has two parameters:
#   df - (degree of freedom).
#   size - The shape of the returned array.

# %%
# Generating a sample for chi squared distribution with degree of freedom 2 with size 2x3:

acz = random.chisquare(df=2, size=(2,3))

print(acz)
# Out:
# [[3.24900955 0.19435753 4.14367298]
#  [1.56440648 1.63874189 6.42764964]]

# %%
# 24.1  Visualization of Chi Square Distribution

sns.distplot(random.chisquare(df=1, size=1000), hist=False)

plt.show()
# Out:
# <ipython-input-118-630ab560eb06>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.chisquare(df=1, size=1000), hist=False)
